# %%
#import module
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#scrapping ulasan sebanyak 1000
from google_play_scraper import Sort,reviews

result,continuation_token=reviews(
    'com.telkom.tracencare',
    lang='id', #bahasa yang digunakan=indonesia
    country= 'id',
    sort=Sort.NEWEST, #memilih data yang terbaru
    count=1000, #data yang diambil 1000
    filter_score_with=None #jika ingin mengambil ulasan sesuai rating 
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  e3fa5db9-09d5-4a48-94f6-6b119f8ff4cd   Qhoiz Mahendra
# 1  75ba9055-c86e-4e92-a9a2-3e6541846de2  Muhammad Ikhsan
# 2  3e4e763e-22e7-4f7a-b73f-7f36424883a1       Ade Afandi
# 3  6c11b569-6f64-4310-9013-35e65e655b78        Nur Sokeh
# 4  0a9800c1-a3a2-48da-aa37-931f05fbe9a2   slamet markeso
#
#                                            userImage               content  \
# 0  https://play-lh.googleusercontent.com/a/AItbvm...           Terimakasih
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...      Mantap betul lah
# 2  https://play-lh.googleusercontent.com/a/AItbvm...               goodjob
# 3  https://play-lh.googleusercontent.com/a/AItbvm...  Sangat mudah diakses
# 4  https://play-lh.googleusercontent.com/a/AItbvm...                  Siip
#
#    score  thumbsUpCount reviewCreatedVersion                  at  \
# 0      5              0                4.4.8 2022-09-14 15:58:24
# ...

# %%
len(df_busu.index)
# Out:
# 1000

# %%
df_busu[['score','content']]
# Out:
#      score                                            content
# 0        5                                        Terimakasih
# 1        5                                   Mantap betul lah
# 2        5                                            goodjob
# 3        5                               Sangat mudah diakses
# 4        5                                               Siip
# ..     ...                                                ...
# 995      2         Minta di update tapi ngak bisa, gimana sih
# 996      2                                        Login susah
# 997      1                                    Gak bisa daftar
# 998      1  aplikasi kont.. bikin emosi,masa tiap login wa...
# 999      1                      Gara² ini semua menjadibsusah
#
# [1000 rows x 2 columns]

# %%
my_df = df_busu[['userName','at','score','content']]

# %%
my_df.to_csv("dataulasan.csv",index=False)
